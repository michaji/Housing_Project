# %% [markdown]
# <a href="https://colab.research.google.com/github/GbotemiB/Housing_Project/blob/main/correction_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/trans_500000.csv' 
path2 = '/content/drive/MyDrive/trans_550000.csv' 
path3 = '/content/drive/MyDrive/trans_600000.csv'

# %%
data = pd.read_csv(path, header=None)
data2 = pd.read_csv(path2, header=None)
data3 = pd.read_csv(path3, header=None)

# %%
len(data), len(data2), len(data3)
# Out:
# (41597, 39347, 12427)

# %%
data.tail()
# Out:
#             0                  1  \
# 41592  507794     By arrangement
# 41593  507795     By arrangement
# 41594  507796  nach Vereinbarung
# 41595  507797         01.04.2022
# 41596  507798     By arrangement
#
#                                                        2   3  \
# 41592  Moderno appartamento "Minergie" 2.5 locali di ...  it
# 41593  Bellissimo rustico nella magica Val di Blenio ...  it
# 41594  composto da cucina arredata, soggiorno, 2 came...  it
# 41595  comprenant: hall, pièce principale, cuisine, s...  fr
# 41596  Siamo a Carona,ad appena 10 minuti da Paradiso...  it
#
#                                                        4
# 41592  Modern 2.5 room apartment "Minergie" of approx...
# 41593  Beautiful cottage in the magical Val di Blenio...
# 41594  composed of fitted kitchen, living room, 2 bed...
# 41595  comprising: hall, main room, kitchen, bathroom...
# 41596  We are in Carona, just 10 minutes from Paradis...

# %%
data2.head()
# Out:
#         0               1                                                  2  \
# 0  516767      01.05.2022  Wir vermieten per 01.05.2022 oder nach Vereinb...
# 1  516768  By arrangement  A Louer 2,5 pièces à Ecublens dans villa au re...
# 2  516769  By arrangement  A Massagno a pochi minuti da Lugano,proponiamo...
# 3  516770      01.03.2022  Renovierte, helle Dachwohnung in einem 2-Famil...
# 4  516771  By arrangement  Affittasi appartamento appena rinnovato (tutte...
#
#     3                                                  4
# 0  de  We rent a quiet and sunny 3 1/2 room apartment...
# 1  fr  For rent 2.5 rooms in Ecublens in a villa on t...
# 2  it  In Massagno, a few minutes from Lugano, we off...
# 3  de  Renovated, bright attic apartment in a 2-famil...
# 4  it  Newly renovated apartment for rent (all the wa...

# %%
data2.tail()
# Out:
#             0                  1  \
# 39342  558223  nach Vereinbarung
# 39343  558224  nach Vereinbarung
# 39344  558225  nach Vereinbarung
# 39345  558226  nach Vereinbarung
# 39346  558227  nach Vereinbarung
#
#                                                        2   3  \
# 39342  Ihr neues zuhauseDiese ruhige und gemütliche 3...  de
# 39343  WOHN(T)RAUM MIT WEITBLICKMitten im Dorfkern vo...  de
# 39344  Wir vermieten diverse Einstellplätze in der Ti...  de
# 39345  Eine virtuelle Besichtigung der Liegenschaft i...  de
# 39346  Au coeur du village de Vuarrens, découvrez ce ...  fr
#
#                                                        4
# 39342  Your new homeThis quiet and cozy 3 ½ room apar...
# 39343  LIVING (D) ROOM WITH A VIEW In the middle of t...
# 39344  We rent various parking spaces in the Escherpa...
# 39345  A virtual tour of the property is already poss...
# 39346  In the heart of the village of Vuarrens, disco...

# %%
data3.head()
# Out:
#         0                  1  \
# 0  569709        Immediately
# 1  569710         15.12.2021
# 2  569711         01.04.2022
# 3  569712         01.04.2022
# 4  569713  nach Vereinbarung
#
#                                                    2   3  \
# 0  Disponiamo in vendita di un bel 4,5 , in casa ...  it
# 1  Situé à 150 mètres de la gare de Bussigny, mag...  fr
# 2  A louer 2 pièces bien situé au 2ème étage en v...  fr
# 3  Lugano centro. Nella elegante cornice della zo...  it
# 4  La Natura e l'Artificio che più caratterizzano...  it
#
#                                                    4
# 0  We have for sale a nice 4.5, in a period house...
# 1  Located 150 meters from Bussigny train station...
# 2  For rent 2 rooms well located on the 2nd floor...
# 3  Lugano center. In the elegant setting of the p...
# 4  The nature and the artifice that most characte...

# %%
data3.tail()
# Out:
#             0               1  \
# 12422  582665  By arrangement
# 12423  582666  By arrangement
# 12424  582667  By arrangement
# 12425  582668      01.04.2022
# 12426  582668      01.04.2022
#
#                                                        2   3  \
# 12422  La société Shifters déménage, besoin de plus d...  fr
# 12423  L'appartement se situe au centre de la commune...  fr
# 12424  Avec un grand potentiel - lumineux avec un emp...  fr
# 12425  Die Wohnung verfügt über eine offene Küche mit...  de
# 12426  Die Wohnung verfügt über eine offene Küche mit...  de
#
#                                                        4
# 12422  Shifters company is moving, need more space!!....
# 12423  The apartment is located in the center of the ...
# 12424  With great potential - bright with an ideal lo...
# 12425  The apartment has an open kitchen with steamer...
# 12426  The apartment has an open kitchen with steamer...

# %%
data.columns = ['a', 'b', 'c', 'd', 'e']

# %%
data.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
data.loc[data['a'] =='51807']
# Out:
#            a           b                                                  c  \
# 50022  51807  15.03.2021  Surface d'activités : garage, industrie, artis...
#
#         d                                                  e
# 50022  fr  Surface of activities: garage, industry, craft...

# %%
data.loc[data['a'] == '51811']
# Out:
#            a           b                                                  c  \
# 50026  51811  01.05.2021  Suchen Sie etwas ganz Spezielles an zentraler ...
#
#         d                                                  e
# 50026  de  Are you looking for something very special in ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
